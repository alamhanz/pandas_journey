# %% [markdown]
# # 5. Working with Columns

# %%
import pandas as pd
import numpy as np

# %%
PATH_DATA = '../mydata/'

# %% [markdown]
# ## Get data

# %%
df_csv = pd.read_csv(PATH_DATA+'food_delivery_datasets.csv')

# %%
df_csv.sample(20)
# df_csv.head(10)
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 208   FOOD-10583               0  2018-08-25T22:12:58.760547          826
# 437   FOOD-10228               0  2018-07-22T19:00:27.448483           10
# 180   FOOD-10248            5000  2018-07-24T18:06:33.002719          671
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 725   FOOD-10841               0  2018-09-16T01:48:18.595402           70
# 637   FOOD-10714               0  2018-09-06T19:31:45.019817         1614
# 393   FOOD-11051               0  2018-09-29T12:59:31.195460         2012
# 594   FOOD-10137               0  2018-07-14T16:31:09.284275         2394
# 212   FOOD-10517               0  2018-08-19T18:34:12.763690         1157
# 376   FOOD-10206               0  2018-07-21T11:22:07.940021         1358
# 537   FOOD-10423           20000  2018-08-10T19:10:39.499978         2684
# 505   FOOD-10805               0  2018-09-14T18:19:31.212897          512
# ...

# %%
df_csv['date_time'] = pd.to_datetime(df_csv['date_time'])

# %%
df_csv[(df_csv.date_time.dt.strftime('%Y-%m-%d') == '2018-09-27')&
       (df_csv.status == 'Completed')].cust_id.tolist()
# Out:
# [193679, 960065, 815241, 103236, 228764, 185161]

# %%
df_csv0 = df_csv.copy()

# %% [markdown]
# ## List down all the columns

# %%
df_csv.columns
# Out:
# Index(['order_id', 'voucher_amount', 'date_time', 'eta_seconds', 'food_price',
#        'cust_id', 'rating', 'delivery_fee', 'resto_id', 'status', 'random_id'],
#       dtype='object')

# %%
list_of_cols = df_csv.columns.tolist()

# %%
list_of_cols
# Out:
# ['order_id',
#  'voucher_amount',
#  'date_time',
#  'eta_seconds',
#  'food_price',
#  'cust_id',
#  'rating',
#  'delivery_fee',
#  'resto_id',
#  'status',
#  'random_id']

# %% [markdown]
# ## New Columns

# %%
df_csv['eta_minutes'] = df_csv['eta_seconds']/60
df_csv['food_price_thousand'] = df_csv['food_price']/1000

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id  \
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587
#
#    eta_minutes  food_price_thousand
# 0    30.000000                 18.9
# ...

# %% [markdown]
# ## Manipulate Columns

# %%
df_csv['random_id'] = df_csv['random_id']*100

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id  \
# 0       18900  1089034     5.0          4000  742638033  Completed  51.114917
# 1      149000   180146     5.0         11000  742767245  Completed  83.293634
# 2       43800   366528     NaN          9000  742618303  Completed  82.802624
# 3       39900   511038     5.0         14000  742541172  Completed  23.937749
# 4       77700  1220358     NaN          4000  742604875  Completed  99.558702
#
#    eta_minutes  food_price_thousand
# 0    30.000000                 18.9
# ...

# %%
df_csv['random_id'] = df_csv['random_id'].round(decimals=2)

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id  \
# 0       18900  1089034     5.0          4000  742638033  Completed      51.11
# 1      149000   180146     5.0         11000  742767245  Completed      83.29
# 2       43800   366528     NaN          9000  742618303  Completed      82.80
# 3       39900   511038     5.0         14000  742541172  Completed      23.94
# 4       77700  1220358     NaN          4000  742604875  Completed      99.56
#
#    eta_minutes  food_price_thousand
# 0    30.000000                 18.9
# ...

# %% [markdown]
# ## Unique Value

# %%
df_csv.rating.unique()
# Out:
# array([ 5., nan,  4.,  3.,  1.])

# %%
df_csv.status.unique()
# Out:
# array(['Completed', 'Cancelled'], dtype=object)

# %%
# df_csv[df_csv['status'] == 'completed'].head()
df_csv[df_csv['status'] == 'Completed'].head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id  \
# 0       18900  1089034     5.0          4000  742638033  Completed      51.11
# 1      149000   180146     5.0         11000  742767245  Completed      83.29
# 2       43800   366528     NaN          9000  742618303  Completed      82.80
# 3       39900   511038     5.0         14000  742541172  Completed      23.94
# 4       77700  1220358     NaN          4000  742604875  Completed      99.56
#
#    eta_minutes  food_price_thousand
# 0    30.000000                 18.9
# ...

# %% [markdown]
# ## Manipulate with Functions

# %%
def to_minutes(x):
    x = round(x/60,3)
    return x

# %%
# df_csv['eta_minute'] = df_csv['eta_seconds'].apply(lambda x : to_minutes(x))
# df_csv['eta_minute'] = df_csv['eta_seconds'].apply(lambda x : round(x/60,3))

df_csv['eta_minute'] = df_csv['eta_seconds'].apply(to_minutes)

# %% [markdown]
# ## Reorder the Columns

# %%
df_csv
# Out:
#         order_id  voucher_amount                  date_time  eta_seconds  \
# 0     FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1     FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2     FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3     FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4     FOOD-10961               0 2018-09-22 17:57:45.523161         1716
# ...          ...             ...                        ...          ...
# 1071  FOOD-10921               0 2018-09-20 15:01:52.152828          900
# 1072  FOOD-10265            5000 2018-07-26 14:43:23.655294         1579
# 1073  FOOD-10534               0 2018-08-21 20:10:59.283185         2606
# 1074  FOOD-10158               0 2018-07-16 14:42:23.214427         2428
# 1075  FOOD-10770               0 2018-09-11 14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
list_of_cols
# Out:
# ['order_id',
#  'voucher_amount',
#  'date_time',
#  'eta_seconds',
#  'food_price',
#  'cust_id',
#  'rating',
#  'delivery_fee',
#  'resto_id',
#  'status',
#  'random_id']

# %%
sorted_cols = np.sort(list_of_cols)

# %%
df_csv_sorted = df_csv[sorted_cols]

# %%
df_csv_sorted.head()
# Out:
#    cust_id                  date_time  delivery_fee  eta_seconds  food_price  \
# 0  1089034 2018-08-12 20:35:08.001006          4000         1800       18900
# 1   180146 2018-09-23 17:44:12.243273         11000         2173      149000
# 2   366528 2018-09-19 18:08:09.387991          9000         1418       43800
# 3   511038 2018-09-21 01:24:35.272499         14000         1903       39900
# 4  1220358 2018-09-22 17:57:45.523161          4000         1716       77700
#
#      order_id  random_id  rating   resto_id     status  voucher_amount
# 0  FOOD-10455      51.11     5.0  742638033  Completed               0
# 1  FOOD-10985      83.29     5.0  742767245  Completed               0
# 2  FOOD-10911      82.80     NaN  742618303  Completed               0
# 3  FOOD-10932      23.94     5.0  742541172  Completed               0
# 4  FOOD-10961      99.56     NaN  742604875  Completed               0

# %% [markdown]
# ## Shifting

# %%
df_csv[['order_id','eta_seconds']]
# Out:
#         order_id  eta_seconds
# 0     FOOD-10455         1800
# 1     FOOD-10985         2173
# 2     FOOD-10911         1418
# 3     FOOD-10932         1903
# 4     FOOD-10961         1716
# ...          ...          ...
# 1071  FOOD-10921          900
# 1072  FOOD-10265         1579
# 1073  FOOD-10534         2606
# 1074  FOOD-10158         2428
# 1075  FOOD-10770         1547
#
# [1076 rows x 2 columns]

# %%
df_csv['eta_seconds_shift'] = df_csv['eta_seconds'].shift()
df_csv['eta_seconds_shift2'] = df_csv['eta_seconds'].shift(2)
df_csv['eta_seconds_reshift'] = df_csv['eta_seconds'].shift(-1)

# %%
df_csv[['order_id','eta_seconds','eta_seconds_shift','eta_seconds_shift2','eta_seconds_reshift']]
# Out:
#         order_id  eta_seconds  eta_seconds_shift  eta_seconds_shift2  \
# 0     FOOD-10455         1800                NaN                 NaN
# 1     FOOD-10985         2173             1800.0                 NaN
# 2     FOOD-10911         1418             2173.0              1800.0
# 3     FOOD-10932         1903             1418.0              2173.0
# 4     FOOD-10961         1716             1903.0              1418.0
# ...          ...          ...                ...                 ...
# 1071  FOOD-10921          900             3040.0               303.0
# 1072  FOOD-10265         1579              900.0              3040.0
# 1073  FOOD-10534         2606             1579.0               900.0
# 1074  FOOD-10158         2428             2606.0              1579.0
# 1075  FOOD-10770         1547             2428.0              2606.0
#
#       eta_seconds_reshift
# 0                  2173.0
# 1                  1418.0
# 2                  1903.0
# 3                  1716.0
# ...

# %% [markdown]
# ## Correlations

# %%
df_csv
# Out:
#         order_id  voucher_amount                  date_time  eta_seconds  \
# 0     FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1     FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2     FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3     FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4     FOOD-10961               0 2018-09-22 17:57:45.523161         1716
# ...          ...             ...                        ...          ...
# 1071  FOOD-10921               0 2018-09-20 15:01:52.152828          900
# 1072  FOOD-10265            5000 2018-07-26 14:43:23.655294         1579
# 1073  FOOD-10534               0 2018-08-21 20:10:59.283185         2606
# 1074  FOOD-10158               0 2018-07-16 14:42:23.214427         2428
# 1075  FOOD-10770               0 2018-09-11 14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
df_csv[['eta_seconds','food_price','delivery_fee']].corr()
# Out:
#               eta_seconds  food_price  delivery_fee
# eta_seconds      1.000000    0.226364      0.053672
# food_price       0.226364    1.000000      0.297295
# delivery_fee     0.053672    0.297295      1.000000

# %% [markdown]
# ## changing type

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id  \
# 0       18900  1089034     5.0          4000  742638033  Completed      51.11
# 1      149000   180146     5.0         11000  742767245  Completed      83.29
# 2       43800   366528     NaN          9000  742618303  Completed      82.80
# 3       39900   511038     5.0         14000  742541172  Completed      23.94
# 4       77700  1220358     NaN          4000  742604875  Completed      99.56
#
#    eta_minutes  food_price_thousand  eta_minute  eta_seconds_shift  \
# ...

# %%
df_csv.dtypes
# Out:
# order_id                       object
# voucher_amount                  int64
# date_time              datetime64[ns]
# eta_seconds                     int64
# food_price                      int64
# cust_id                         int64
# rating                        float64
# delivery_fee                    int64
# resto_id                        int64
# status                         object
# random_id                     float64
# eta_minutes                   float64
# food_price_thousand           float64
# eta_minute                    float64
# eta_seconds_shift             float64
# eta_seconds_shift2            float64
# eta_seconds_reshift           float64
# dtype: object

# %%
df_csv['resto_id'] = df_csv['resto_id'].astype(str)

# %%
df_csv.dtypes
# Out:
# order_id                       object
# voucher_amount                  int64
# date_time              datetime64[ns]
# eta_seconds                     int64
# food_price                      int64
# cust_id                         int64
# rating                        float64
# delivery_fee                    int64
# resto_id                       object
# status                         object
# random_id                     float64
# eta_minutes                   float64
# food_price_thousand           float64
# eta_minute                    float64
# eta_seconds_shift             float64
# eta_seconds_shift2            float64
# eta_seconds_reshift           float64
# dtype: object

# %% [markdown]
# ## Standardization

# %% [markdown]
# <!-- ![pandas read options](../img/read_pandas.png) -->
# <img src="https://i.ibb.co/RNd6416/standard.png" alt="drawing" width="250"/>

# %%
df_csv[['order_id','delivery_fee']]
# Out:
#         order_id  delivery_fee
# 0     FOOD-10455          4000
# 1     FOOD-10985         11000
# 2     FOOD-10911          9000
# 3     FOOD-10932         14000
# 4     FOOD-10961          4000
# ...          ...           ...
# 1071  FOOD-10921          4000
# 1072  FOOD-10265          7000
# 1073  FOOD-10534         15000
# 1074  FOOD-10158          9000
# 1075  FOOD-10770          9000
#
# [1076 rows x 2 columns]

# %%
Mu = df_csv['delivery_fee'].mean()
Su = df_csv['delivery_fee'].std()

df_csv['delivery_fee_SS'] = (df_csv['delivery_fee']-Mu)/Su

# %%
df_csv[['order_id','delivery_fee','delivery_fee_SS']].head()
# Out:
#      order_id  delivery_fee  delivery_fee_SS
# 0  FOOD-10455          4000        -0.781247
# 1  FOOD-10985         11000         0.259863
# 2  FOOD-10911          9000        -0.037597
# 3  FOOD-10932         14000         0.706053
# 4  FOOD-10961          4000        -0.781247

# %%
round(df_csv['delivery_fee_SS'].mean(),3),round(df_csv['delivery_fee_SS'].std(),3)
# Out:
# (0.0, 1.0)
