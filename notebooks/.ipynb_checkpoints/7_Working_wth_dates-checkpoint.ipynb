# %% [markdown]
# # 7. Working with Dates

# %%
import pandas as pd
import numpy as np

# %%
PATH_DATA = '../mydata/'

# %% [markdown]
# ## Get data

# %%
df_csv = pd.read_csv(PATH_DATA+'food_delivery_datasets.csv')

# %%
df_csv.head()
# df_csv.head(10)
# Out:
#      order_id  voucher_amount                   date_time  eta_seconds  \
# 0  FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1  FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2  FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3  FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4  FOOD-10961               0  2018-09-22T17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587

# %%
df_csv0 = df_csv.copy()

# %% [markdown]
# ## Dates and times
#
# source : https://docs.python.org/3/library/datetime.html
#
#
# <img src="https://i.ibb.co/ssD39Sn/time-table.png" alt="drawing" width="650"/>

# %%
date = pd.to_datetime("5th of July, 2015")
date
# Out:
# Timestamp('2015-07-05 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Sunday'

# %%
date.strftime('%w')
# Out:
# '0'

# %%
date.strftime('%Y')
# Out:
# '2015'

# %%
date.strftime('%Y-%m-%d')
# Out:
# '2015-07-05'

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08',
#                '2015-07-09', '2015-07-10', '2015-07-11', '2015-07-12',
#                '2015-07-13', '2015-07-14', '2015-07-15', '2015-07-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                   date_time  eta_seconds  \
# 0  FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1  FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2  FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3  FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4  FOOD-10961               0  2018-09-22T17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587

# %%
df_csv.dtypes
# Out:
# order_id           object
# voucher_amount      int64
# date_time          object
# eta_seconds         int64
# food_price          int64
# cust_id             int64
# rating            float64
# delivery_fee        int64
# resto_id            int64
# status             object
# random_id         float64
# dtype: object

# %%
df_csv['date_time']
# Out:
# 0       2018-08-12T20:35:08.001006
# 1       2018-09-23T17:44:12.243273
# 2       2018-09-19T18:08:09.387991
# 3       2018-09-21T01:24:35.272499
# 4       2018-09-22T17:57:45.523161
#                    ...
# 1071    2018-09-20T15:01:52.152828
# 1072    2018-07-26T14:43:23.655294
# 1073    2018-08-21T20:10:59.283185
# 1074    2018-07-16T14:42:23.214427
# 1075    2018-09-11T14:18:19.494258
# Name: date_time, Length: 1076, dtype: object

# %%
df_csv['date_time'] = pd.to_datetime(df_csv['date_time'])

# %%
df_csv['date_time']
# Out:
# 0      2018-08-12 20:35:08.001006
# 1      2018-09-23 17:44:12.243273
# 2      2018-09-19 18:08:09.387991
# 3      2018-09-21 01:24:35.272499
# 4      2018-09-22 17:57:45.523161
#                   ...
# 1071   2018-09-20 15:01:52.152828
# 1072   2018-07-26 14:43:23.655294
# 1073   2018-08-21 20:10:59.283185
# 1074   2018-07-16 14:42:23.214427
# 1075   2018-09-11 14:18:19.494258
# Name: date_time, Length: 1076, dtype: datetime64[ns]

# %%
df_csv['date_time'].dt.strftime('%B, %Y')
# Out:
# 0          August, 2018
# 1       September, 2018
# 2       September, 2018
# 3       September, 2018
# 4       September, 2018
#              ...
# 1071    September, 2018
# 1072         July, 2018
# 1073       August, 2018
# 1074         July, 2018
# 1075    September, 2018
# Name: date_time, Length: 1076, dtype: object

# %%
df_csv['date_time'].dt.strftime('%Y-%m-%d')
# Out:
# 0       2018-08-12
# 1       2018-09-23
# 2       2018-09-19
# 3       2018-09-21
# 4       2018-09-22
#            ...
# 1071    2018-09-20
# 1072    2018-07-26
# 1073    2018-08-21
# 1074    2018-07-16
# 1075    2018-09-11
# Name: date_time, Length: 1076, dtype: object

# %%
df_csv['date_time'].dt.strftime('%Y-%m-%d').unique()
# Out:
# array(['2018-08-12', '2018-09-23', '2018-09-19', '2018-09-21',
#        '2018-09-22', '2018-07-01', '2018-08-13', '2018-08-03',
#        '2018-08-06', '2018-07-14', '2018-09-02', '2018-08-11',
#        '2018-08-26', '2018-08-04', '2018-09-18', '2018-07-24',
#        '2018-08-07', '2018-07-21', '2018-07-04', '2018-07-28',
#        '2018-08-23', '2018-09-08', '2018-07-22', '2018-08-09',
#        '2018-09-04', '2018-08-02', '2018-09-30', '2018-09-25',
#        '2018-07-15', '2018-09-09', '2018-07-29', '2018-08-22',
#        '2018-08-25', '2018-08-15', '2018-09-07', '2018-08-20',
#        '2018-07-31', '2018-07-08', '2018-07-11', '2018-08-21',
#        '2018-07-12', '2018-08-19', '2018-09-17', '2018-09-20',
#        '2018-09-16', '2018-08-31', '2018-09-10', '2018-07-10',
#        '2018-09-06', '2018-09-24', '2018-07-30', '2018-08-28',
#        '2018-08-10', '2018-09-15', '2018-07-20', '2018-07-05',
#        '2018-07-19', '2018-09-14', '2018-07-25', '2018-07-26',
# ...

# %%
len(df_csv['date_time'].dt.strftime('%Y-%m-%d').unique())
# Out:
# 92

# %% [markdown]
# ## Filter with date

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587

# %%
df_csv.dtypes
# Out:
# order_id                  object
# voucher_amount             int64
# date_time         datetime64[ns]
# eta_seconds                int64
# food_price                 int64
# cust_id                    int64
# rating                   float64
# delivery_fee               int64
# resto_id                   int64
# status                    object
# random_id                float64
# dtype: object

# %%
df_csv[df_csv['date_time']<'2018-08-01']
# Out:
#         order_id  voucher_amount                  date_time  eta_seconds  \
# 5     FOOD-10004               0 2018-07-01 14:24:06.719768         2344
# 12    FOOD-10008            3000 2018-07-01 17:27:58.151546         1416
# 13    FOOD-10141               0 2018-07-14 17:57:45.108952         2514
# 21    FOOD-10243               0 2018-07-24 11:05:19.481372         1353
# 23    FOOD-10216               0 2018-07-21 23:41:55.508813         2016
# ...          ...             ...                        ...          ...
# 1062  FOOD-10087           15000 2018-07-09 12:25:52.984375         1430
# 1064  FOOD-10079               0 2018-07-08 16:24:18.530533         1246
# 1066  FOOD-10074               0 2018-07-08 13:41:27.613831          845
# 1072  FOOD-10265            5000 2018-07-26 14:43:23.655294         1579
# 1074  FOOD-10158               0 2018-07-16 14:42:23.214427         2428
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
## make the date-time be the index
df_csv2 = df_csv.set_index('date_time')
df_csv2.head()
# Out:
#                               order_id  voucher_amount  eta_seconds  \
# date_time
# 2018-08-12 20:35:08.001006  FOOD-10455               0         1800
# 2018-09-23 17:44:12.243273  FOOD-10985               0         2173
# 2018-09-19 18:08:09.387991  FOOD-10911               0         1418
# 2018-09-21 01:24:35.272499  FOOD-10932               0         1903
# 2018-09-22 17:57:45.523161  FOOD-10961               0         1716
#
#                             food_price  cust_id  rating  delivery_fee  \
# date_time
# 2018-08-12 20:35:08.001006       18900  1089034     5.0          4000
# 2018-09-23 17:44:12.243273      149000   180146     5.0         11000
# 2018-09-19 18:08:09.387991       43800   366528     NaN          9000
# 2018-09-21 01:24:35.272499       39900   511038     5.0         14000
# 2018-09-22 17:57:45.523161       77700  1220358     NaN          4000
#
#                              resto_id     status  random_id
# date_time
# ...

# %%
df_csv2.loc['2018-09-12':'2018-09-13']
# Out:
#                               order_id  voucher_amount  eta_seconds  \
# date_time
# 2018-09-12 13:46:23.877145  FOOD-10779               0         2129
# 2018-09-12 14:53:51.090161  FOOD-10780               0         2337
# 2018-09-13 17:58:59.063309  FOOD-10791            5000         2587
# 2018-09-12 13:07:33.118473  FOOD-10778            5000         2398
# 2018-09-13 12:26:05.844827  FOOD-10787               0         2114
# 2018-09-13 12:24:00.542603  FOOD-10786               0         3117
# 2018-09-12 20:34:42.930772  FOOD-10784               0         1462
# 2018-09-13 17:20:16.885310  FOOD-10790               0         2118
# 2018-09-13 18:58:37.400931  FOOD-10794               0         1875
# 2018-09-13 16:20:54.062093  FOOD-10789               0         1926
# 2018-09-12 19:39:03.403840  FOOD-10783               0         1546
# 2018-09-13 15:14:21.933027  FOOD-10788               0         3632
# 2018-09-13 18:54:38.203475  FOOD-10793               0          198
# ...

# %% [markdown]
# ## between time

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587

# %%
date_bench = pd.to_datetime('2018-07-01') ## --> pertama kali rilis

# %%
df_csv['date_time']-date_bench
# Out:
# 0      42 days 20:35:08.001006
# 1      84 days 17:44:12.243273
# 2      80 days 18:08:09.387991
# 3      82 days 01:24:35.272499
# 4      83 days 17:57:45.523161
#                  ...
# 1071   81 days 15:01:52.152828
# 1072   25 days 14:43:23.655294
# 1073   51 days 20:10:59.283185
# 1074   15 days 14:42:23.214427
# 1075   72 days 14:18:19.494258
# Name: date_time, Length: 1076, dtype: timedelta64[ns]

# %%
(df_csv['date_time']-date_bench).apply(lambda x : x.days)
# Out:
# 0       42
# 1       84
# 2       80
# 3       82
# 4       83
#         ..
# 1071    81
# 1072    25
# 1073    51
# 1074    15
# 1075    72
# Name: date_time, Length: 1076, dtype: int64

# %%
(df_csv['date_time']-date_bench).apply(lambda x : x.seconds)
# Out:
# 0       74108
# 1       63852
# 2       65289
# 3        5075
# 4       64665
#         ...
# 1071    54112
# 1072    53003
# 1073    72659
# 1074    52943
# 1075    51499
# Name: date_time, Length: 1076, dtype: int64

# %%
df_csv['delta_bench'] = (df_csv['date_time']-date_bench).apply(lambda x : x.days)

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id  \
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587
#
#    delta_bench
# 0           42
# 1           84
# 2           80
# ...

# %%
today_date = pd.to_datetime('2018-08-01')

# %%
df_csv['delta_bench2'] = (today_date - df_csv['date_time']).apply(lambda x : x.days)

# %%
df_csv.head()
# Out:
#      order_id  voucher_amount                  date_time  eta_seconds  \
# 0  FOOD-10455               0 2018-08-12 20:35:08.001006         1800
# 1  FOOD-10985               0 2018-09-23 17:44:12.243273         2173
# 2  FOOD-10911               0 2018-09-19 18:08:09.387991         1418
# 3  FOOD-10932               0 2018-09-21 01:24:35.272499         1903
# 4  FOOD-10961               0 2018-09-22 17:57:45.523161         1716
#
#    food_price  cust_id  rating  delivery_fee   resto_id     status  random_id  \
# 0       18900  1089034     5.0          4000  742638033  Completed   0.511149
# 1      149000   180146     5.0         11000  742767245  Completed   0.832936
# 2       43800   366528     NaN          9000  742618303  Completed   0.828026
# 3       39900   511038     5.0         14000  742541172  Completed   0.239377
# 4       77700  1220358     NaN          4000  742604875  Completed   0.995587
#
#    delta_bench  delta_bench2
# 0           42           -12
# ...

# %%
df_csv[(df_csv.delta_bench2>0)&(df_csv.delta_bench2<=7)]
# Out:
#         order_id  voucher_amount                  date_time  eta_seconds  \
# 21    FOOD-10243               0 2018-07-24 11:05:19.481372         1353
# 26    FOOD-10281               0 2018-07-28 12:41:57.633675         1827
# 43    FOOD-10287               0 2018-07-28 19:05:22.766498         2316
# 44    FOOD-10292           10000 2018-07-29 00:59:09.189530         1458
# 78    FOOD-10309               0 2018-07-30 19:57:57.257522         2470
# ...          ...             ...                        ...          ...
# 1019  FOOD-10263               0 2018-07-26 13:30:14.227458         3260
# 1023  FOOD-10254               0 2018-07-25 13:05:16.948437         2554
# 1049  FOOD-10260               0 2018-07-25 18:44:26.630766         1187
# 1050  FOOD-10300               0 2018-07-29 19:08:14.623026         1238
# 1072  FOOD-10265            5000 2018-07-26 14:43:23.655294         1579
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %% [markdown]
# ## Date Range

# %%
pd.date_range('2015-07-03', periods=8, freq='H')
# Out:
# DatetimeIndex(['2015-07-03 00:00:00', '2015-07-03 01:00:00',
#                '2015-07-03 02:00:00', '2015-07-03 03:00:00',
#                '2015-07-03 04:00:00', '2015-07-03 05:00:00',
#                '2015-07-03 06:00:00', '2015-07-03 07:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.date_range('2015-07-03', periods=8, freq='D')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8, freq='M')
# Out:
# DatetimeIndex(['2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31',
#                '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2015-07-03', '2015-10-06')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10',
#                '2015-07-11', '2015-07-12', '2015-07-13', '2015-07-14',
#                '2015-07-15', '2015-07-16', '2015-07-17', '2015-07-18',
#                '2015-07-19', '2015-07-20', '2015-07-21', '2015-07-22',
#                '2015-07-23', '2015-07-24', '2015-07-25', '2015-07-26',
#                '2015-07-27', '2015-07-28', '2015-07-29', '2015-07-30',
#                '2015-07-31', '2015-08-01', '2015-08-02', '2015-08-03',
#                '2015-08-04', '2015-08-05', '2015-08-06', '2015-08-07',
#                '2015-08-08', '2015-08-09', '2015-08-10', '2015-08-11',
#                '2015-08-12', '2015-08-13', '2015-08-14', '2015-08-15',
#                '2015-08-16', '2015-08-17', '2015-08-18', '2015-08-19',
#                '2015-08-20', '2015-08-21', '2015-08-22', '2015-08-23',
# ...
